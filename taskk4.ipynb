# %%
import pandas as pd

df = pd.read_json("archive/arxiv-metadata-oai-snapshot.json",lines=True)

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 3
#       1 import pandas as pd
# ----> 3 df = pd.read_json("archive/arxiv-metadata-oai-snapshot.json",lines=True)
#       5 print(df.head())
#
# File C:\Python313\Lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File C:\Python313\Lib\site-packages\pandas\io\json\_json.py:1012, in JsonReader.read(self)
#    1010         data = ensure_str(self.data)
#    1011         data_lines = data.split("\n")
# -> 1012         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1013 else:
# ...
